# %% [markdown]
# # Netflix Data Analysis Project

# %%
# first we import our dataset

import pandas as pd

data = pd.read_csv("8. Netflix Dataset.csv")

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# #### getting some basic information of the dataset

# %%
data.head() # it shows the top 5 records of the dataset
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.tail() # this function shows the bottom 5 records
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
data.shape # usign this we can get how many rows and columns
# Out:
# (7789, 11)

# %%
data.size # these function shows the how many elements are in the dataset
# Out:
# 85679

# %%
data.columns # these function shows all the columns names are present in the dataset
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data.dtypes # these command shows the datatype of all the the columns
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data.info() # these function shows all the information about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# ## for the data analysis we have to find the duplicates records are present in the dataset or not
#
#         if there are any duplicate values remove them

# %%
# we use duplicate function to find duplicates 

data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.shape
# Out:
# (7789, 11)

# %%
data[data.duplicated()] # we dont have any duplicate value
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
data.drop_duplicates(inplace = True) #these command is use to remove the duplicate values

# %%
data.shape
# Out:
# (7787, 11)

# %% [markdown]
# ### 2. find null values in the dataset

# %%
data.isnull()  # to check the null values
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %% [markdown]
# where is the true is there in the dataset
#
#         means we have null values there

# %%
data.isnull().sum() # it will show the count of all null present in the each column
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
# we show the null values with the heat map

# import seaborn library to show the heatmap 
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# we will choose any random shows and we will se the information about that show or movie

# %%
data['Title'] # for to select the title column
# Out:
# 0                                            3%
# 1                                         07:19
# 2                                         23:59
# 3                                             9
# 4                                            21
#                          ...
# 7784                                       Zozo
# 7785                                     Zubaan
# 7786                          Zulu Man in Japan
# 7787                      Zumbo's Just Desserts
# 7788    ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# Name: Title, Length: 7787, dtype: object

# %%
data['Title'].isin(['House of cards'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Name: Title, Length: 7787, dtype: bool

# %%
data[data['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
data['Title'].str.contains('House of Cards')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Name: Title, Length: 7787, dtype: bool

# %%
data[data['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# next we show in which year the most of the tv shows and movies are launched using bargraph

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data['Dates'] = pd.to_datetime(data['Release_Date']) # using thses command we can make new column that contains all the records that release year have

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Dates           datetime64[ns]
# dtype: object

# %%
data['Dates'].dt.year.value_counts()  # it count all the years
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Dates, dtype: int64

# %% [markdown]
# ## Bar graph

# %%
data['Dates'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# #### now we can see how many movies and Tv shows are in dataset and we can show it using Bar plot

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description      Dates
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
data.groupby('Category')  # using these group by method we can simply make groups of our categories

# %%
data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
data.groupby('Category').Category.count().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# #### now we can see all the movies that are released in year 2017

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# now we create a new column that will only contain the year of the movies

data['Year'] = data['Dates'].dt.year

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# now we filter the year column

movies_2017 = data[(data['Category'] == 'Movie') & (data['Year'] == 2017)]

# %%
pd.set_option('display.max_rows' , 5000)
pd.set_option('display.max_columns' , 5000)
print(movies_2017)
# Out:
#      Show_Id Category                                              Title  \
# 3         s4    Movie                                                  9
# 9        s10    Movie                                               1920
# 10       s11    Movie                                               1922
# 33       s34    Movie                                       #realityhigh
# 40       s41    Movie                                        Çarsi Pazar
# 42       s43    Movie                        Çok Filim Hareketler Bunlar
# 46       s47    Movie                                   1 Chance 2 Dance
# 47       s48    Movie                                      1 Mile to You
# 49       s50    Movie                                     10 jours en or
# 54       s55    Movie                                         100 Meters
# 67       s68    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# 74       s75    Movie              1898: Our Last Men in the Philippines
# ...

# %% [markdown]
# ### now we can display all the tv shows that were released only in the INDIA

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
TVShows_India = data[(data['Category'] == 'TV Show') & (data['Country'] == 'India')]

# %%
print(TVShows_India)
# Out:
#      Show_Id Category                                          Title  \
# 86       s87  TV Show                   21 Sarfarosh: Saragarhi 1897
# 132     s133  TV Show                                      7 (Seven)
# 340     s341  TV Show                                   Agent Raghav
# 364     s365  TV Show                                   Akbar Birbal
# 533     s534  TV Show                            Anjaan: Rural Myths
# 534     s535  TV Show                    Anjaan: Special Crimes Unit
# 686     s687  TV Show                    Bad Boy Billionaires: India
# 698     s699  TV Show                     Badalte Rishton Ki Dastaan
# 750     s751  TV Show                                  Bard of Blood
# 856     s857  TV Show                                         Betaal
# 879     s880  TV Show                                    Bh Se Bhade
# 880     s881  TV Show                             Bhaag Beanie Bhaag
# 881     s882  TV Show                                 Bhaage Re Mann
# ...

# %%
data[(data['Category'] == 'TV Show') & (data['Country'] == 'India')]['Title']
# Out:
# 86                       21 Sarfarosh: Saragarhi 1897
# 132                                         7 (Seven)
# 340                                      Agent Raghav
# 364                                      Akbar Birbal
# 533                               Anjaan: Rural Myths
# 534                       Anjaan: Special Crimes Unit
# 686                       Bad Boy Billionaires: India
# 698                        Badalte Rishton Ki Dastaan
# 750                                     Bard of Blood
# 856                                            Betaal
# 879                                       Bh Se Bhade
# 880                                Bhaag Beanie Bhaag
# 881                                    Bhaage Re Mann
# 1316                                     Chhota Bheem
# 1377    ChuChu TV Nursery Rhymes & Kids Songs (Hindi)
# 1412                                  Classic Legends
# 1463                                  College Romance
# ...

# %% [markdown]
# Now We see the top 10 Directors who give the Highest number of TV Shows and Movies in Netflix?

# %%
data['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: Director, dtype: int64

# %%
data['Director'].value_counts().head(10).plot(kind = "bar")
# Out:
# <Axes: >

# %% [markdown]
# ### now we see the rocords where "category is movie and Type is comedies" or "Country is United Kingdom".

# %%
comedy_movies = data[( data['Category'] == 'Movie' ) & ( ( data['Type'] == 'Comedies') | (data['Country'] == 'United Kingdom' ) )]

# %%
pd.set_option('display.max_rows' , 5000)
pd.set_option('display.max_columns' , 5000)

print(comedy_movies.shape)
print(comedy_movies)
# Out:
# (281, 13)
#      Show_Id Category                                              Title  \
# 19       s20    Movie                                                '89
# 33       s34    Movie                                       #realityhigh
# 72       s73    Movie                                           17 Again
# 82       s83    Movie                                2036 Origin Unknown
# 84       s85    Movie                                          21 & Over
# 93       s94    Movie                                  27: Gone Too Soon
# 148     s149    Movie                               A Bad Moms Christmas
# 174     s175    Movie                        A Futile and Stupid Gesture
# 181     s182    Movie             A Grand Night In: The Story of Aardman
# 196     s197    Movie                                     A Little Chaos
# 212     s213    Movie                                     A Patch of Fog
# 240     s241    Movie                                   A Thousand Words
# ...

# %% [markdown]
# ### Now we find in how many movies Tom Cruise was the actor

# %%
data [ (data['Cast'] == 'Tom Cruise') ]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Dates, Year]
# Index: []

# %%
data [ (data['Cast'].str.contains('Tom Cruise')) ]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[161], line 1
# ----> 1 data [ (data['Cast'].str.contains('Tom Cruise')) ]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:3795, in DataFrame.__getitem__(self, key)
#    3792     return self.where(key)
#    3794 # Do we have a (boolean) 1d indexer?
# -> 3795 if com.is_bool_indexer(key):
#    3796     return self._getitem_bool_array(key)
#    3798 # We are left with two options: a single key, and a collection of keys,
#    3799 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\common.py:135, in is_bool_indexer(key)
#     131     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     132     if lib.infer_dtype(key_array) == "boolean" and isna(key_array).any():
# ...

# %%
data_new = data.dropna()

# %%
data_new [ (data_new['Cast'].str.contains('Tom Cruise')) ]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description
# 3860  Through chance, human action, past history and...
# 5071  A fast-talking yuppie is forced to slow down w...

# %% [markdown]
# ### Find the Actor who is working in most of the shows and movies

# %%
data['Cast'].value_counts().head(1)
# Out:
# David Attenborough    18
# Name: Cast, dtype: int64

# %% [markdown]
# ### what are the diffrent ratings defined by netflix

# %%
data['Rating'].nunique()
# Out:
# 14

# %%
data_new['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ### now we find How many movies got the "TV-14" rating in canada?

# %%
data[ (data['Category'] == 'Movie') & ( data['Rating'] == 'TV-14' ) & (data['Country'] == 'Canada')]

# %% [markdown]
# ### now we find How many tv shows got 'R' Rating after year 2018?

# %%
data[( data['Category'] == 'TV Show' ) & (data['Rating'] == 'R') & (data['Year'] > 2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#         Release_Date Rating  Duration      Type  \
# 6437  April 25, 2019      R  1 Season  TV Shows
#
#                                             Description      Dates    Year
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %% [markdown]
# ### What is the maximum duration of a Movie / show on Netflix ?

# %%
data.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
# data is in the object format

# we have to convert this into numeric format

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description      Dates    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
# we have to split data into 2 column 

data[['Minute' , 'Unit']] = data['Duration'].str.split(' ' , expand = True)

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description      Dates    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minute     Unit
# 0      4  Seasons
# 1     93      min

# %%
data.Minute.max()
# Out:
# '99'

# %%
minute_data = data.Minute.astype(str).astype(int)

# %%
minute_data.max()
# Out:
# 312

# %%
minute_data.min()
# Out:
# 1

# %%
minute_data.mean()
# Out:
# 69.12276871709258

# %% [markdown]
# ### Now we find which country has highest number of TV Shows

# %%
data_TVShows = data[data['Category'] == 'TV Show']

# %%
data_TVShows.head(2)
# Out:
#   Show_Id Category Title     Director  \
# 0      s1  TV Show    3%          NaN
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey     July 1, 2017
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5  TV-MA   1 Season    International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description      Dates    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 5  A genetics professor experiments with a treatm... 2017-07-01  2017.0
#
#   Minute     Unit
# 0      4  Seasons
# 5      1   Season

# %%
data_TVShows.Country.value_counts()
# Out:
# United States                                                    705
# United Kingdom                                                   204
# Japan                                                            157
# South Korea                                                      147
# India                                                             71
# Taiwan                                                            68
# Canada                                                            59
# France                                                            46
# Australia                                                         46
# Spain                                                             45
# China                                                             36
# Mexico                                                            35
# Turkey                                                            27
# Brazil                                                            26
# ...

# %%
data_TVShows.Country.value_counts().head(10)
# Out:
# United States     705
# United Kingdom    204
# Japan             157
# South Korea       147
# India              71
# Taiwan             68
# Canada             59
# France             46
# Australia          46
# Spain              45
# Name: Country, dtype: int64

# %%
data_TVShows.Country.value_counts().head(10).plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# ### the Data set is unsorted and we want sort the data year

# %%
data.sort_values(by = 'Year')
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...

# %%
data_new.sort_values(by = 'Year').head(50)
# Out:
#      Show_Id Category                                             Title  \
# 7115   s7114    Movie                              To and From New York
# 5766   s5766    Movie                                          Splatter
# 3248   s3249    Movie                           Just Another Love Story
# 3840   s3841    Movie                       Mad Ron's Prevues from Hell
# 3221   s3222    Movie                            Joseph: King of Dreams
# 7151   s7150    Movie                                Too Young the Hero
# 2962   s2963    Movie                       In Defense of a Married Man
# 232     s233    Movie                        A Stoning in Fulham County
# 6847   s6846    Movie                              The Ryan White Story
# 2622   s2623    Movie                                      Hard Lessons
# 2041   s2042    Movie                                     Even the Rain
# 5833   s5833    Movie                                    Strange Voices
# ...
